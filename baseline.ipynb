# %%
# !source venv/bin/activate && python3 kahan/run_kahan_agent.py --model "gpt-4o-mini" --market_group cattle-totalfarmmarketing gold-investrade
# Out:
# Kahan Agent started. Log file at: results/agent_logs/agent_run_2026-07-17_153348.txt
# --- Starting Knowledge Generation ---
# Generating knowledge for oil-leaprate...
# Generating knowledge for corn-totalfarmmarketing...
# Generating knowledge for gold-investrade...
# Generating knowledge for currency-vtmarkets...
# Generating knowledge for cattle-totalfarmmarketing...
# Generating knowledge for soybean-totalfarmmarketing...
# Generating knowledge for dairy-totalfarmmarketing...
# Generating knowledge for gold-leaprate...
# Generating knowledge for currency-leaprate...
# Generating knowledge for oil-investrade...
# Generating knowledge for equity_market-vtmarkets...
# Generating knowledge for wheat-totalfarmmarketing...
# Generating knowledge for treasury-investrade...
# Generating knowledge for lean_hog-totalfarmmarketing...
# Generating knowledge for equity_market-investrade...
# --- Knowledge Generation Complete ---
# --- Starting Narrative Generation ---
# ...
